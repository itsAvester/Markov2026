# %%
#PROBLEM 1D
import numpy as np

def delivery():
    i = 0
    time = 0
    while i < 20:
        if i == 0:
            wait = np.random.exponential(1)
            time += wait
            i += 1
        else:
            total_rate = 2
            wait = np.random.exponential(1/2)
            time += wait
            if np.random.rand()<1/2:
                i += 1
            else:
                i -= 1 
    return time

N = 1000

times = [delivery() for i in range(N)]
sample_mean = sum(times)/len(times)
sample_variance = np.var(times)

theoretical_mean = (20*21)/2

print(sample_mean)
print(theoretical_mean)
print(sample_variance)
# Out:
# 218.10398639492084
# 210.0
# 31949.004917889295
